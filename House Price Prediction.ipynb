# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#loading dataset
data = pd.read_csv("housingprice.csv")

# %%
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  households  median_income  median_house_value
# 0         322         126         8.3252              452600
# 1        2401        1138         8.3014              358500
# 2         496         177         7.2574              352100
# 3         558         219         5.6431              341300
# 4         565         259         3.8462              342200

# %%
#data exploration
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  int64
# dtypes: float64(4), int64(5)
# memory usage: 1.4 MB

# %%
data.dropna(inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  int64
#  3   total_rooms         20433 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  int64
#  6   households          20433 non-null  int64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  int64
# dtypes: float64(4), int64(5)
# memory usage: 1.6 MB

# %%
#spillting the data
from sklearn.model_selection import train_test_split
X = data.drop(['median_house_value'],axis=1)

y = data['median_house_value']

# %%
X#data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
#        population  households  median_income
# 0             322         126         8.3252
# 1            2401        1138         8.3014
# 2             496         177         7.2574
# 3             558         219         5.6431
# 4             565         259         3.8462
# ...           ...         ...            ...
# 20635         845         330         1.5603
# 20636         356         114         2.5568
# 20637        1007         433         1.7000
# 20638         741         349         1.8672
# 20639        1387         530         2.3886
#
# [20433 rows x 8 columns]

# %%
y#data
# Out:
# 0        452600
# 1        358500
# 2        352100
# 3        341300
# 4        342200
#           ...
# 20635     78100
# 20636     77100
# 20637     92300
# 20638     84700
# 20639     89400
# Name: median_house_value, Length: 20433, dtype: int64

# %%
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.2)

# %%
train_data = X_train.join(y_train)

# %%
train_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 13370    -117.54     34.12                   4        17577          2819.0
# 15567    -117.03     33.12                  25         3142           446.0
# 8951     -118.37     34.03                  39          213            44.0
# 8885     -118.50     34.03                  44         2146           394.0
# 19123    -122.65     38.24                  24         1948           310.0
# ...          ...       ...                 ...          ...             ...
# 20329    -119.02     34.26                  40         1498           292.0
# 3872     -118.54     34.21                  32         2593           566.0
# 7260     -118.18     34.01                  39          322            82.0
# 9772     -121.23     36.33                  23         2095           536.0
# 19001    -121.92     38.34                   2         7747          1133.0
#
#        population  households  median_income  median_house_value
# 13370        7766        2473         5.1333              181800
# 15567        1286         419         5.4663              248300
# 8951          138          52         2.1250              196400
# 8885          851         355         6.4800              500001
# 19123         922         313         4.9500              243600
# ...           ...         ...            ...                 ...
# 20329         707         249         3.7974              228700
# 3872         1596         547         3.9886              199200
# 7260          319          90         2.6364              148800
# 9772         1858         457         3.0543               92400
# 19001        3481        1083         6.1112              181000
#
# [16346 rows x 9 columns]

# %%
#plotting histogram
train_data.hist(figsize=(15,8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
#General correlation analysis
train_data.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924158           -0.109030     0.044643
# latitude            -0.924158  1.000000            0.011348    -0.036146
# housing_median_age  -0.109030  0.011348            1.000000    -0.356618
# total_rooms          0.044643 -0.036146           -0.356618     1.000000
# total_bedrooms       0.067840 -0.064894           -0.316265     0.929972
# population           0.100375 -0.108768           -0.300559     0.865434
# households           0.054272 -0.069256           -0.298431     0.918571
# median_income       -0.012892 -0.083981           -0.119590     0.203812
# median_house_value  -0.045190 -0.146964            0.106044     0.138303
#
#                     total_bedrooms  population  households  median_income  \
# longitude                 0.067840    0.100375    0.054272      -0.012892
# latitude                 -0.064894   -0.108768   -0.069256      -0.083981
# housing_median_age       -0.316265   -0.300559   -0.298431      -0.119590
# total_rooms               0.929972    0.865434    0.918571       0.203812
# total_bedrooms            1.000000    0.886681    0.979611      -0.002539
# population                0.886681    1.000000    0.915599       0.010285
# households                0.979611    0.915599    1.000000       0.018851
# median_income            -0.002539    0.010285    0.018851       1.000000
# median_house_value        0.054352   -0.021309    0.069910       0.688862
#
#                     median_house_value
# longitude                    -0.045190
# latitude                     -0.146964
# housing_median_age            0.106044
# total_rooms                   0.138303
# total_bedrooms                0.054352
# population                   -0.021309
# households                    0.069910
# median_income                 0.688862
# median_house_value            1.000000

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot = True,cmap = "YlGnBu")
# Out:
# <Axes: >

# %%
#Data processing
train_data['total_rooms'] = np.log(train_data['total_rooms']+1)
train_data['total_bedrooms'] = np.log(train_data['total_bedrooms']+1)
train_data['population'] = np.log(train_data['population']+1)
train_data['households'] = np.log(train_data['households']+1)

# %%
train_data.hist(figsize=(15,10))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'bedrooms_ratio'}>],
#        [<Axes: title={'center': 'household_rooms'}>,
#         <Axes: title={'center': 'median_house_value'}>, <Axes: >]],
#       dtype=object)

# %%
plt.figure(figsize=(15,8))#for getting values of expensive houses
sns.scatterplot(x="latitude",y="longitude",data = train_data,hue="median_house_value",palette="coolwarm")
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
train_data['bedrooms_ratio'] = train_data['total_bedrooms']/train_data['total_rooms']

# %%
train_data['household_rooms'] = train_data['total_rooms']/train_data['households']

# %%
plt.figure(figsize=(15,8))
sns.heatmap(train_data.corr(), annot = True,cmap = "YlGnBu")
# Out:
# <Axes: >

# %%
#linear regression model
from sklearn.linear_model import LinearRegression

X_train,y_train = train_data.drop(['median_house_value'],axis = 1),train_data['median_house_value']


reg = LinearRegression()
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
test_data = X_test.join(y_test)
test_data['total_rooms'] = np.log(test_data['total_rooms']+1)
test_data['total_bedrooms'] = np.log(test_data['total_bedrooms']+1)
test_data['population'] = np.log(test_data['population']+1)
test_data['households'] = np.log(test_data['households']+1)
test_data['bedrooms_ratio'] = test_data['total_bedrooms']/test_data['total_rooms']
test_data['household_rooms'] = test_data['total_rooms']/test_data['households']
X_test,y_test = test_data.drop(['median_house_value'],axis=1),test_data['median_house_value']

# %%
X_test
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 5156     -118.28     33.96                  42     7.380879        5.991465
# 18078    -122.01     37.27                  28     8.249575        6.161207
# 18350    -122.15     37.41                  29     6.161207        4.644391
# 5138     -118.28     33.97                  40     7.687539        6.466145
# 16283    -121.29     37.93                  24     7.271704        5.863631
# ...          ...       ...                 ...          ...             ...
# 5507     -118.43     33.99                  42     7.847372        6.326149
# 19756    -122.25     40.17                  19     8.065579        6.447306
# 17518    -121.91     37.34                  35     7.691657        6.410175
# 895      -121.96     37.54                  14     8.538367        7.096721
# 7448     -118.18     33.95                  39     7.660114        6.363028
#
#        population  households  median_income  bedrooms_ratio  household_rooms
# 5156     7.366445    5.961005         1.7656        0.811755         1.238194
# 18078    7.255591    6.175867        10.6750        0.746851         1.335776
# 18350    5.886104    4.477337         7.0309        0.753812         1.376088
# 5138     7.809947    6.448889         1.5521        0.841120         1.192072
# 16283    7.166266    5.837730         2.7829        0.806363         1.245639
# ...           ...         ...            ...             ...              ...
# 5507     7.192182    6.295266         4.8750        0.806149         1.246551
# 19756    7.462789    6.466145         1.9727        0.799361         1.247355
# 17518    7.085064    6.333280         2.8042        0.833393         1.214482
# 895      7.915348    7.011214         3.9909        0.831157         1.217816
# 7448     7.596894    6.270988         2.9094        0.830670         1.221516
#
# [4087 rows x 10 columns]

# %%
X_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 13370    -117.54     34.12                   4     9.774403        7.944492
# 15567    -117.03     33.12                  25     8.052933        6.102559
# 8951     -118.37     34.03                  39     5.365976        3.806662
# 8885     -118.50     34.03                  44     7.671827        5.978886
# 19123    -122.65     38.24                  24     7.575072        5.739793
# ...          ...       ...                 ...          ...             ...
# 20329    -119.02     34.26                  40     7.312553        5.680173
# 3872     -118.54     34.21                  32     7.860956        6.340359
# 7260     -118.18     34.01                  39     5.777652        4.418841
# 9772     -121.23     36.33                  23     7.647786        6.285998
# 19001    -121.92     38.34                   2     8.955190        7.033506
#
#        population  households  median_income  bedrooms_ratio  household_rooms
# 13370    8.957639    7.813592         5.1333        0.812785         1.250949
# 15567    7.160069    6.040255         5.4663        0.757806         1.333211
# 8951     4.934474    3.970292         2.1250        0.709407         1.351532
# 8885     6.747587    5.874931         6.4800        0.779330         1.305858
# 19123    6.827629    5.749393         4.9500        0.757721         1.317543
# ...           ...         ...            ...             ...              ...
# 20329    6.562444    5.521461         3.7974        0.776770         1.324387
# 3872     7.375882    6.306275         3.9886        0.806563         1.246529
# 7260     5.768321    4.510860         2.6364        0.764816         1.280832
# 9772     7.527794    6.126869         3.0543        0.821937         1.248237
# 19001    8.155362    6.988413         6.1112        0.785411         1.281434
#
# [16346 rows x 10 columns]

# %%
reg.score(X_test,y_test)
# Out:
# 0.6614761434266162

# %%
y_test.head(10)
# Out:
# 5156      96700
# 18078    500001
# 18350    475000
# 5138      90100
# 16283     61800
# 6158     159900
# 14614    133300
# 3067      56500
# 1212      92200
# 12765     97500
# Name: median_house_value, dtype: int64
